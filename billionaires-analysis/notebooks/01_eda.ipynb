# %% [markdown]
# # 📊 Notebook 01 — Exploratory Data Analysis
# **Data loading → cleaning → statistical testing → wealth inequality → geospatial**
#
# All business logic lives in `src/billionaires/`.  This notebook is for
# storytelling, not for defining logic.

# %%
# If you cloned the repo and ran `pip install -e .` this just works.
import sys, warnings
sys.path.insert(0, "../src")
warnings.filterwarnings("ignore")

from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import ttest_ind, f_oneway, chi2_contingency
import numpy as np

from billionaires.data   import load_raw, validate_schema, clean
from billionaires.features import build_features
from billionaires.viz import (
    wealth_distribution, age_distribution, top_categories,
    gender_breakdown, self_made_comparison,
    lorenz_curve, choropleth_count, choropleth_wealth,
    correlation_heatmap,
)

FIGURES_DIR = Path("../reports/figures")
FIGURES_DIR.mkdir(parents=True, exist_ok=True)
DATA_PATH   = Path("../data/raw/Billionaires Statistics Dataset.csv")
print("✅ Ready")
# Out:
# ✅ Ready

# %% [markdown]
# ## 1. Load & Validate

# %%
df_raw = load_raw(DATA_PATH)
validate_schema(df_raw)
print(f"Raw shape: {df_raw.shape}")
df_raw.head(3)
# Out:
# Raw shape: (2640, 35)
#    rank  finalWorth          category                personName   age  \
# 0     1      211000  Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000        Automotive                 Elon Musk  51.0
# 2     3      114000        Technology                Jeff Bezos  59.0
#
#          country    city         source        industries  \
# 0         France   Paris           LVMH  Fashion & Retail
# 1  United States  Austin  Tesla, SpaceX        Automotive
# 2  United States  Medina         Amazon        Technology
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 0               France  ...                1.1   $2,715,518,274,227
# 1        United States  ...                7.5  $21,427,700,000,000
# 2        United States  ...                7.5  $21,427,700,000,000
#
#   gross_tertiary_education_enrollment  \
# 0                                65.6
# 1                                88.2
# 2                                88.2
#
#   gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                      102.5                    82.5
# 1                                      101.8                    78.5
# 2                                      101.8                    78.5
#
#   tax_revenue_country_country total_tax_rate_country population_country  \
# 0                        24.2                   60.7         67059887.0
# 1                         9.6                   36.6        328239523.0
# 2                         9.6                   36.6        328239523.0
#
#   latitude_country longitude_country
# 0        46.227638          2.213749
# 1        37.090240        -95.712891
# 2        37.090240        -95.712891
#
# [3 rows x 35 columns]

# %%
# Missing-value summary table
miss = pd.DataFrame({
    "null_count": df_raw.isnull().sum(),
    "null_%": (df_raw.isnull().mean() * 100).round(2),
    "dtype": df_raw.dtypes,
    "unique": df_raw.nunique(),
}).sort_values("null_%", ascending=False)
miss[miss["null_%"] > 0]
# Out:
#                                             null_count  null_%    dtype  \
# organization                                      2315   87.69   object
# title                                             2301   87.16   object
# residenceStateRegion                              1893   71.70   object
# state                                             1887   71.48   object
# cpi_country                                        184    6.97  float64
# cpi_change_country                                 184    6.97  float64
# tax_revenue_country_country                        183    6.93  float64
# life_expectancy_country                            182    6.89  float64
# gross_tertiary_education_enrollment                182    6.89  float64
# total_tax_rate_country                             182    6.89  float64
# gross_primary_education_enrollment_country         181    6.86  float64
# gdp_country                                        164    6.21   object
# latitude_country                                   164    6.21  float64
# longitude_country                                  164    6.21  float64
# population_country                                 164    6.21  float64
# birthYear                                           76    2.88  float64
# birthDay                                            76    2.88  float64
# birthMonth                                          76    2.88  float64
# birthDate                                           76    2.88   object
# city                                                72    2.73   object
# age                                                 65    2.46  float64
# country                                             38    1.44   object
# firstName                                            3    0.11   object
#
#                                             unique
# organization                                   294
# title                                           97
# residenceStateRegion                             5
# state                                           45
# cpi_country                                     63
# cpi_change_country                              44
# tax_revenue_country_country                     57
# life_expectancy_country                         54
# gross_tertiary_education_enrollment             63
# total_tax_rate_country                          63
# gross_primary_education_enrollment_country      60
# gdp_country                                     68
# latitude_country                                68
# longitude_country                               68
# population_country                              68
# birthYear                                       77
# birthDay                                        31
# birthMonth                                      12
# birthDate                                     2060
# city                                           741
# age                                             79
# country                                         78
# firstName                                     1770

# %% [markdown]
# ## 2. Clean & Engineer Features

# %%
df_clean = clean(df_raw)
df       = build_features(df_clean)
print(f"Working shape: {df.shape}")
df.dtypes
# Out:
# Working shape: (2640, 43)
# rank                                             int64
# finalWorth                                       int64
# category                                        object
# personName                                      object
# age                                            float64
# country                                         object
# city                                            object
# source                                          object
# industries                                      object
# countryOfCitizenship                            object
# organization                                    object
# selfMade                                         int64
# status                                          object
# gender                                          object
# birthDate                                       object
# lastName                                        object
# firstName                                       object
# title                                           object
# date                                            object
# state                                           object
# residenceStateRegion                            object
# birthYear                                      float64
# birthMonth                                     float64
# birthDay                                       float64
# cpi_country                                    float64
# cpi_change_country                             float64
# gdp_country                                     object
# gross_tertiary_education_enrollment            float64
# gross_primary_education_enrollment_country     float64
# life_expectancy_country                        float64
# tax_revenue_country_country                    float64
# total_tax_rate_country                         float64
# population_country                             float64
# latitude_country                               float64
# longitude_country                              float64
# log_worth                                      float64
# age_group                                     category
# wealth_per_decade                              float64
# continent                                       object
# category_enc                                     int64
# country_enc                                      int64
# gender_enc                                       int64
# continent_enc                                    int64
# dtype: object

# %%
# Extended descriptive statistics
df[["finalWorth", "age", "wealth_per_decade"]].describe(
    percentiles=[.05, .25, .50, .75, .90, .95, .99]
).T.style.format("{:.2f}").background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_f589a_row0_col0, #T_f589a_row1_col0, #T_f589a_row1_col1, #T_f589a_row1_col2, #T_f589a_row1_col3, #T_f589a_row1_col4, #T_f589a_row1_col5, #T_f589a_row1_col6, #T_f589a_row1_col7, #T_f589a_row1_col8, #T_f589a_row1_col9, #T_f589a_row1_col10, #T_f589a_row1_col11, #T_f589a_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f589a_row0_col1, #T_f589a_row0_col2, #T_f589a_row0_col3, #T_f589a_row0_col4, #T_f589a_row0_col5, #T_f589a_row0_col6, #T_f589a_row0_col7, #T_f589a_row0_col8, #T_f589a_row0_col9, #T_f589a_row0_col10, #T_f589a_row0_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f589a_row2_col1, #T_f589a_row2_col7 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_f589a_row2_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f589a_row2_col3 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_f589a_row2_col4 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_f589a_row2_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_f589a_row2_col6 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_f589a_row2_col8, #T_f589a_row2_col9 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_f589a_row2_col10 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_f589a_row2_col11 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# </style>
# <table id="T_f589a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f589a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f589a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f589a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f589a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f589a_level0_col4" class="col_heading level0 col4" >5%</th>
#       <th id="T_f589a_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_f589a_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_f589a_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_f589a_level0_col8" class="col_heading level0 col8" >90%</th>
#       <th id="T_f589a_level0_col9" class="col_heading level0 col9" >95%</th>
#       <th id="T_f589a_level0_col10" class="col_heading level0 col10" >99%</th>
#       <th id="T_f589a_level0_col11" class="col_heading level0 col11" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f589a_level0_row0" class="row_heading level0 row0" >finalWorth</th>
#       <td id="T_f589a_row0_col0" class="data row0 col0" >2640.00</td>
#       <td id="T_f589a_row0_col1" class="data row0 col1" >4623.79</td>
#       <td id="T_f589a_row0_col2" class="data row0 col2" >9834.24</td>
#       <td id="T_f589a_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_f589a_row0_col4" class="data row0 col4" >1100.00</td>
#       <td id="T_f589a_row0_col5" class="data row0 col5" >1500.00</td>
#       <td id="T_f589a_row0_col6" class="data row0 col6" >2300.00</td>
#       <td id="T_f589a_row0_col7" class="data row0 col7" >4200.00</td>
#       <td id="T_f589a_row0_col8" class="data row0 col8" >8000.00</td>
#       <td id="T_f589a_row0_col9" class="data row0 col9" >13320.00</td>
#       <td id="T_f589a_row0_col10" class="data row0 col10" >41808.00</td>
#       <td id="T_f589a_row0_col11" class="data row0 col11" >211000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f589a_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_f589a_row1_col0" class="data row1 col0" >2640.00</td>
#       <td id="T_f589a_row1_col1" class="data row1 col1" >65.15</td>
#       <td id="T_f589a_row1_col2" class="data row1 col2" >13.11</td>
#       <td id="T_f589a_row1_col3" class="data row1 col3" >18.00</td>
#       <td id="T_f589a_row1_col4" class="data row1 col4" >43.00</td>
#       <td id="T_f589a_row1_col5" class="data row1 col5" >56.00</td>
#       <td id="T_f589a_row1_col6" class="data row1 col6" >65.00</td>
#       <td id="T_f589a_row1_col7" class="data row1 col7" >74.00</td>
#       <td id="T_f589a_row1_col8" class="data row1 col8" >82.00</td>
#       <td id="T_f589a_row1_col9" class="data row1 col9" >87.00</td>
#       <td id="T_f589a_row1_col10" class="data row1 col10" >94.00</td>
#       <td id="T_f589a_row1_col11" class="data row1 col11" >101.00</td>
#     </tr>
#     <tr>
#       <th id="T_f589a_level0_row2" class="row_heading level0 row2" >wealth_per_decade</th>
#       <td id="T_f589a_row2_col0" class="data row2 col0" >2640.00</td>
#       <td id="T_f589a_row2_col1" class="data row2 col1" >723.08</td>
#       <td id="T_f589a_row2_col2" class="data row2 col2" >1549.81</td>
#       <td id="T_f589a_row2_col3" class="data row2 col3" >102.04</td>
#       <td id="T_f589a_row2_col4" class="data row2 col4" >159.42</td>
#       <td id="T_f589a_row2_col5" class="data row2 col5" >235.79</td>
#       <td id="T_f589a_row2_col6" class="data row2 col6" >368.42</td>
#       <td id="T_f589a_row2_col7" class="data row2 col7" >666.67</td>
#       <td id="T_f589a_row2_col8" class="data row2 col8" >1271.56</td>
#       <td id="T_f589a_row2_col9" class="data row2 col9" >2089.89</td>
#       <td id="T_f589a_row2_col10" class="data row2 col10" >6866.98</td>
#       <td id="T_f589a_row2_col11" class="data row2 col11" >35294.12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Wealth Distribution

# %%
fig = wealth_distribution(df, save_path=FIGURES_DIR / "01_wealth_dist.png")
plt.show()
print(f"Skewness raw: {df['finalWorth'].skew():.2f}  |  "
      f"log-transformed: {df['log_worth'].skew():.2f}")
# Out:
# Skewness raw: 10.01  |  log-transformed: 1.32

# %% [markdown]
# ## 4. Category, Gender & Self-Made Analysis

# %%
top_categories(df).show()

# %%
gender_breakdown(df).show()

# %%
self_made_comparison(df).show()

# %%
fig = age_distribution(df, save_path=FIGURES_DIR / "02_age_dist.png")
plt.show()

# %% [markdown]
# ## 5. Correlation

# %%
fig = correlation_heatmap(df, save_path=FIGURES_DIR / "03_corr.png")
plt.show()

# %% [markdown]
# ## 6. Statistical Hypothesis Tests

# %%
print("━" * 55)
print("TEST 1 — t-test: Self-Made vs Inherited Net Worth")
print("━" * 55)
sm  = df[df["selfMade"] == 1]["finalWorth"]
inh = df[df["selfMade"] == 0]["finalWorth"]
lev_p = stats.levene(sm, inh).pvalue
equal_var = lev_p > 0.05
t, p = ttest_ind(sm, inh, equal_var=equal_var)
print(f"Levene p={lev_p:.4f}  equal_var={equal_var}")
print(f"t={t:.3f}  p={p:.6f}")
print("→", "Significant" if p < 0.05 else "Not significant", "at α=0.05")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# TEST 1 — t-test: Self-Made vs Inherited Net Worth
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Levene p=0.3763  equal_var=True
# t=-1.224  p=0.220940
# → Not significant at α=0.05

# %%
print("━" * 55)
print("TEST 2 — ANOVA: Net Worth across top 8 categories")
print("━" * 55)
top8   = df["category"].value_counts().head(8).index
groups = [df[df["category"] == c]["finalWorth"].values for c in top8]
f, p   = f_oneway(*groups)
print(f"F={f:.3f}  p={p:.6f}")
print("→", "Means differ" if p < 0.05 else "No difference", "across categories")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# TEST 2 — ANOVA: Net Worth across top 8 categories
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# F=4.456  p=0.000062
# → Means differ across categories

# %%
print("━" * 55)
print("TEST 3 — Chi-squared: Gender × Self-Made")
print("━" * 55)
ct = pd.crosstab(df["gender"], df["selfMade"])
chi2, p, dof, _ = chi2_contingency(ct)
print(ct)
print(f"\nchi2={chi2:.3f}  p={p:.4f}  dof={dof}")
print("→", "Dependent" if p < 0.05 else "Independent")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# TEST 3 — Chi-squared: Gender × Self-Made
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# selfMade    0     1
# gender
# F         241    96
# M         587  1716
#
# chi2=287.150  p=0.0000  dof=1
# → Dependent

# %% [markdown]
# ## 7. Wealth Inequality — Gini & Lorenz

# %%
fig = lorenz_curve(df, save_path=FIGURES_DIR / "04_lorenz.png")
plt.show()

# Concentration
p99 = df["finalWorth"].quantile(0.99)
p90 = df["finalWorth"].quantile(0.90)
total = df["finalWorth"].sum()
print(f"Top  1% share: {df[df['finalWorth']>=p99]['finalWorth'].sum()/total*100:.1f}%")
print(f"Top 10% share: {df[df['finalWorth']>=p90]['finalWorth'].sum()/total*100:.1f}%")
# Out:
# Top  1% share: 18.0%
# Top 10% share: 47.8%

# %% [markdown]
# ## 8. Geospatial

# %%
choropleth_count(df).show()

# %%
choropleth_wealth(df).show()
